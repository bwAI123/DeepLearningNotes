# %%
from typing import List, Dict, Optional, Union, Tuple



def add_ab(a: int, b: int = 1) -> int:
    return a + b


c = add_ab(100, 20)
print(c)
print(add_ab(100))
print(add_ab(1001, 2.5))
# Out:
# 120
# 101
# 1003.5
