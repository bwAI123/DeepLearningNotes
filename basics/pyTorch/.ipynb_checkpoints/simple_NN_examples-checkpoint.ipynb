# %%
# 导入PyTorch库
import torch
import torch.nn as nn

# 定义输入层大小、隐藏层大小、输出层大小和批量大小
n_in, n_h, n_out, batch_size = 10, 5, 1, 10

# 创建虚拟输入数据和目标数据
x = torch.randn(batch_size, n_in)  # 随机生成输入数据bath_size x n_in,符合标准正态分布
y = torch.tensor([[1.0], [0.0], [0.0], 
                 [1.0], [1.0], [1.0], [0.0], [0.0], [1.0], [1.0]])  # 目标输出数据
print(x)
print(y)
# Out:
# tensor([[ 0.0941, -0.7919,  0.8997, -0.1411,  1.1189,  0.9616,  0.0641, -0.1471,
#           0.5121,  1.6135],
#         [ 1.6457, -0.2350, -1.7505,  0.6626, -0.1098, -0.5722,  1.0586, -1.1367,
#           0.2835,  0.8437],
#         [ 0.5202,  0.0204,  0.7814,  0.9267, -0.1719, -0.2985,  1.2352,  0.9701,
#           2.5800, -0.1408],
#         [-0.1441, -0.4376, -1.9441, -1.5790,  0.9207,  0.0779, -1.0600,  1.4342,
#          -0.0609,  1.0865],
#         [ 0.8890, -0.0637,  0.6094, -2.0647,  0.5344, -0.4405,  0.4097,  2.7133,
#          -0.2592, -1.5701],
#         [ 1.3468,  0.4504,  0.0701, -0.3998,  0.2321,  0.2601,  2.2843,  0.4771,
#           0.2708,  0.1068],
#         [-0.1876,  0.4092, -0.3098, -2.2869,  0.4722, -0.2446, -0.4094,  0.1922,
#          -1.2032, -0.0591],
#         [ 0.6365, -0.0796, -0.5223,  0.7412, -0.6222,  0.8553,  2.1463, -1.4219,
#          -0.4642,  1.0936],
#         [ 0.2480,  0.3359, -0.2259, -1.6676, -0.3989, -2.4768, -0.4981, -1.3306,
#           0.7775, -0.8271],
#         [-0.3309, -1.6798, -1.0298, -0.1572, -0.6724, -0.0353,  2.2155, -2.2492,
#           0.4211,  0.0661]])
# tensor([[1.],
#         [0.],
#         [0.],
#         [1.],
#         [1.],
#         [1.],
#         [0.],
#         [0.],
#         [1.],
#         [1.]])

# %%
# 创建顺序模型，包含线性层、ReLU激活函数和Sigmoid激活函数
model = nn.Sequential(
   nn.Linear(n_in, n_h),  # 输入层到隐藏层的线性变换
   nn.ReLU(),            # 隐藏层的ReLU激活函数
   nn.Linear(n_h, n_out),  # 隐藏层到输出层的线性变换
   nn.Sigmoid()           # 输出层的Sigmoid激活函数
)

print(type(model))
# Out:
# <class 'torch.nn.modules.container.Sequential'>

# %% [markdown]
# `nn.Sequential` 一个列表式的神经网络，数据从第一层进去，依次经过每一层，从最后一层出来，中间不需要你写任何 forward 逻辑。

# %%
# 定义均方误差损失函数和随机梯度下降优化器
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)  # 学习率为0.01
print(type(criterion))
print(isinstance(criterion, torch.nn.Module))   # True
# Out:
# <class 'torch.nn.modules.loss.MSELoss'>
# True

# %% [markdown]
# `cirterion = torch.nn.MSELoss`; `criterion` 是 `torch.nn.MSELoss` 类的一个实例对象，本质上是一个可调用对象（callable），可以像函数一样使用。

# %%
# 执行梯度下降算法进行模型训练
for epoch in range(50):  # 迭代50次
   y_pred = model(x)  # 前向传播，计算预测值
   loss = criterion(y_pred, y)  # 计算损失
   print('epoch: ', epoch, 'loss: ', loss.item())  # 打印损失
   print(loss)

   optimizer.zero_grad()  # 清零梯度
   loss.backward()  # 反向传播，计算梯度
   optimizer.step()  # 更新模型参数
# Out:
# epoch:  0 loss:  0.24959120154380798
# tensor(0.2496, grad_fn=<MseLossBackward0>)
# epoch:  1 loss:  0.2494097650051117
# tensor(0.2494, grad_fn=<MseLossBackward0>)
# epoch:  2 loss:  0.24922852218151093
# tensor(0.2492, grad_fn=<MseLossBackward0>)
# epoch:  3 loss:  0.24904747307300568
# tensor(0.2490, grad_fn=<MseLossBackward0>)
# epoch:  4 loss:  0.24886663258075714
# tensor(0.2489, grad_fn=<MseLossBackward0>)
# epoch:  5 loss:  0.24868592619895935
# tensor(0.2487, grad_fn=<MseLossBackward0>)
# epoch:  6 loss:  0.24850544333457947
# tensor(0.2485, grad_fn=<MseLossBackward0>)
# epoch:  7 loss:  0.2483251541852951
# tensor(0.2483, grad_fn=<MseLossBackward0>)
# epoch:  8 loss:  0.24814505875110626
# tensor(0.2481, grad_fn=<MseLossBackward0>)
# epoch:  9 loss:  0.24796512722969055
# tensor(0.2480, grad_fn=<MseLossBackward0>)
# epoch:  10 loss:  0.24778537452220917
# tensor(0.2478, grad_fn=<MseLossBackward0>)
# epoch:  11 loss:  0.2476058006286621
# tensor(0.2476, grad_fn=<MseLossBackward0>)
# epoch:  12 loss:  0.24742642045021057
# tensor(0.2474, grad_fn=<MseLossBackward0>)
# epoch:  13 loss:  0.24724721908569336
# tensor(0.2472, grad_fn=<MseLossBackward0>)
# epoch:  14 loss:  0.24706821143627167
# tensor(0.2471, grad_fn=<MseLossBackward0>)
# epoch:  15 loss:  0.2468893826007843
# tensor(0.2469, grad_fn=<MseLossBackward0>)
# epoch:  16 loss:  0.24671073257923126
# tensor(0.2467, grad_fn=<MseLossBackward0>)
# epoch:  17 loss:  0.24653223156929016
# tensor(0.2465, grad_fn=<MseLossBackward0>)
# epoch:  18 loss:  0.2463539093732834
# tensor(0.2464, grad_fn=<MseLossBackward0>)
# epoch:  19 loss:  0.24617576599121094
# tensor(0.2462, grad_fn=<MseLossBackward0>)
# epoch:  20 loss:  0.245997816324234
# tensor(0.2460, grad_fn=<MseLossBackward0>)
# epoch:  21 loss:  0.24582000076770782
# tensor(0.2458, grad_fn=<MseLossBackward0>)
# epoch:  22 loss:  0.24564237892627716
# tensor(0.2456, grad_fn=<MseLossBackward0>)
# epoch:  23 loss:  0.24546495079994202
# tensor(0.2455, grad_fn=<MseLossBackward0>)
# epoch:  24 loss:  0.24528768658638
# tensor(0.2453, grad_fn=<MseLossBackward0>)
# epoch:  25 loss:  0.24511055648326874
# tensor(0.2451, grad_fn=<MseLossBackward0>)
# epoch:  26 loss:  0.24493363499641418
# tensor(0.2449, grad_fn=<MseLossBackward0>)
# epoch:  27 loss:  0.24475686252117157
# tensor(0.2448, grad_fn=<MseLossBackward0>)
# epoch:  28 loss:  0.2445802390575409
# tensor(0.2446, grad_fn=<MseLossBackward0>)
# epoch:  29 loss:  0.24440380930900574
# tensor(0.2444, grad_fn=<MseLossBackward0>)
# epoch:  30 loss:  0.2442275583744049
# tensor(0.2442, grad_fn=<MseLossBackward0>)
# epoch:  31 loss:  0.24405141174793243
# tensor(0.2441, grad_fn=<MseLossBackward0>)
# epoch:  32 loss:  0.24387547373771667
# tensor(0.2439, grad_fn=<MseLossBackward0>)
# epoch:  33 loss:  0.24369969964027405
# tensor(0.2437, grad_fn=<MseLossBackward0>)
# epoch:  34 loss:  0.24352410435676575
# tensor(0.2435, grad_fn=<MseLossBackward0>)
# epoch:  35 loss:  0.2433485984802246
# tensor(0.2433, grad_fn=<MseLossBackward0>)
# epoch:  36 loss:  0.24317331612110138
# tensor(0.2432, grad_fn=<MseLossBackward0>)
# epoch:  37 loss:  0.2429981529712677
# tensor(0.2430, grad_fn=<MseLossBackward0>)
# epoch:  38 loss:  0.24282316863536835
# tensor(0.2428, grad_fn=<MseLossBackward0>)
# epoch:  39 loss:  0.24264833331108093
# tensor(0.2426, grad_fn=<MseLossBackward0>)
# epoch:  40 loss:  0.24247364699840546
# tensor(0.2425, grad_fn=<MseLossBackward0>)
# epoch:  41 loss:  0.24229910969734192
# tensor(0.2423, grad_fn=<MseLossBackward0>)
# epoch:  42 loss:  0.2421247661113739
# tensor(0.2421, grad_fn=<MseLossBackward0>)
# epoch:  43 loss:  0.24195054173469543
# tensor(0.2420, grad_fn=<MseLossBackward0>)
# epoch:  44 loss:  0.2417764663696289
# tensor(0.2418, grad_fn=<MseLossBackward0>)
# epoch:  45 loss:  0.2416025698184967
# tensor(0.2416, grad_fn=<MseLossBackward0>)
# epoch:  46 loss:  0.24142880737781525
# tensor(0.2414, grad_fn=<MseLossBackward0>)
# epoch:  47 loss:  0.24125519394874573
# tensor(0.2413, grad_fn=<MseLossBackward0>)
# epoch:  48 loss:  0.24108171463012695
# tensor(0.2411, grad_fn=<MseLossBackward0>)
# epoch:  49 loss:  0.2409084141254425
# tensor(0.2409, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## 手搓版本

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# 生成一些随机数据
n_samples = 100
data = torch.randn(n_samples, 2)  # 生成 100 个二维数据点
labels = (data[:, 0]**2 + data[:, 1]**2 < 1).float().unsqueeze(1)  # 点在圆内为1，圆外为0

# 可视化数据
plt.scatter(data[:, 0], data[:, 1], c=labels.squeeze(), cmap='coolwarm')
plt.title("Generated Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# 定义前馈神经网络
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        # 定义神经网络的层
        self.fc1 = nn.Linear(2, 4)  # 输入层有 2 个特征，隐藏层有 4 个神经元
        self.fc2 = nn.Linear(4, 1)  # 隐藏层输出到 1 个神经元（用于二分类）
        self.sigmoid = nn.Sigmoid()  # 二分类激活函数

    def forward(self, x):
        x = torch.relu(self.fc1(x))  # 使用 ReLU 激活函数
        x = self.sigmoid(self.fc2(x))  # 输出层使用 Sigmoid 激活函数
        return x

# 实例化模型
model = SimpleNN()

# 定义损失函数和优化器
criterion = nn.BCELoss()  # 二元交叉熵损失
optimizer = optim.SGD(model.parameters(), lr=0.1)  # 使用随机梯度下降优化器

# 训练
epochs = 100
for epoch in range(epochs):
    # 前向传播
    outputs = model(data)
    loss = criterion(outputs, labels)

    # 反向传播
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # 每 10 轮打印一次损失
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')

# 可视化决策边界
def plot_decision_boundary(model, data):
    x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
    y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
    xx, yy = torch.meshgrid(torch.arange(x_min, x_max, 0.1), torch.arange(y_min, y_max, 0.1), indexing='ij')
    grid = torch.cat([xx.reshape(-1, 1), yy.reshape(-1, 1)], dim=1)
    predictions = model(grid).detach().numpy().reshape(xx.shape)
    plt.contourf(xx, yy, predictions, levels=[0, 0.5, 1], cmap='coolwarm', alpha=0.7)
    plt.scatter(data[:, 0], data[:, 1], c=labels.squeeze(), cmap='coolwarm', edgecolors='k')
    plt.title("Decision Boundary")
    plt.show()

plot_decision_boundary(model, data)
