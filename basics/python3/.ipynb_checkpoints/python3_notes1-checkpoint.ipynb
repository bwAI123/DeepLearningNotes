# %% [markdown]
# ## 字典
#
# 返回键值对，可以使用items()

# %%
#!/usr/bin/python3
tinydict = {'Name': 'Runoob', 'Age': 7}
 
print ("Value : %s" %  tinydict.items())
# Out:
# Value : dict_items([('Name', 'Runoob'), ('Age', 7)])

# %%
"""
Examples:　https://coral-omics.readthedocs.io/en/latest/tutorials/coral_tutorial.html
"""
import os
import urllib.request

#data_dir = "Mouse_thymus_data"
data_dir = "./"
os.makedirs(data_dir, exist_ok=True)


files = {
    "adata_thymus1_annotation.h5ad": "https://ndownloader.figshare.com/files/59752970",
    "adata_ADT.h5ad": "https://ndownloader.figshare.com/files/59752967",
    "adata_RNA_low.h5ad": "https://ndownloader.figshare.com/files/59752973",
}

for filename, url in files.items():
    filepath = os.path.join(data_dir, filename)

    test_url = os.path.join(url, filename,)
    print(f"File to download from {test_url}")
    if os.path.exists(filepath):
        print(f"Already exists: {filepath}")
    else:
        print(f"Downloading {filename}...")
        #urllib.request.urlretrieve(url, filepath)
        print(f"  Saved to {filepath}")
# Out:
# File to download from https://ndownloader.figshare.com/files/59752970\adata_thymus1_annotation.h5ad
# Downloading adata_thymus1_annotation.h5ad...
#   Saved to ./adata_thymus1_annotation.h5ad
# File to download from https://ndownloader.figshare.com/files/59752967\adata_ADT.h5ad
# Downloading adata_ADT.h5ad...
#   Saved to ./adata_ADT.h5ad
# File to download from https://ndownloader.figshare.com/files/59752973\adata_RNA_low.h5ad
# Downloading adata_RNA_low.h5ad...
#   Saved to ./adata_RNA_low.h5ad

# %% [markdown]
# > os.path.join()根据系统自动选择分隔符。
